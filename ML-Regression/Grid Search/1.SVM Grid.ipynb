# %%
import pandas as pd

# %%
dataset = pd.read_csv('insurance_pre.csv')
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset, dtype=int, drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children',  'sex_male', 'smoker_yes']]
dependent = dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train, y_test = train_test_split(independent, dependent, test_size=0.30, random_state=0)

# %%
# x_test

# %%
from sklearn.preprocessing import StandardScaler

sc= StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)
x_test
# Out:
# array([[ 0.89459283, -0.08863026, -0.06746417,  1.02378711, -0.50466988],
#        [ 0.53757957, -0.22180837, -0.06746417, -0.97676557, -0.50466988],
#        [ 0.60898222,  1.57449152,  0.76341038,  1.02378711,  1.98149332],
#        ...,
#        [ 1.10880078,  1.20785059, -0.89833872,  1.02378711, -0.50466988],
#        [ 1.75142463,  1.34905148, -0.06746417,  1.02378711, -0.50466988],
#        [ 1.60861933, -0.92299913, -0.89833872, -0.97676557, -0.50466988]])

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR

param_grid = {'kernel': ['rbf', 'linear', 'poly','sigmoid'],
              'C' : [10,100], 'gamma': ['scale','auto']      
             }

grid = GridSearchCV(SVR(), param_grid, refit=True, verbose=3, n_jobs=-1)
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100], 'gamma': ['scale', 'auto'],
#                          'kernel': ['rbf', 'linear', 'poly', 'sigmoid']},
#              verbose=3)

# %%
re = grid.cv_results_

# %%
table = pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.095401      0.005058         0.050019        0.002185      10
# 1        0.073918      0.004502         0.010284        0.004806      10
# 2        0.070571      0.007571         0.012433        0.005027      10
# 3        0.087923      0.004973         0.017550        0.002788      10
# 4        0.080917      0.004292         0.052864        0.005434      10
# 5        0.069469      0.007173         0.012713        0.004659      10
# 6        0.073243      0.003227         0.014612        0.004524      10
# 7        0.096849      0.003618         0.016634        0.002945      10
# 8        0.090717      0.002761         0.055028        0.003619     100
# 9        0.088767      0.003467         0.011724        0.004526     100
# 10       0.074569      0.004836         0.012988        0.005263     100
# 11       0.090746      0.005823         0.021747        0.004032     100
# 12       0.090948      0.006559         0.053503        0.003038     100
# 13       0.091027      0.005189         0.015403        0.003433     100
# 14       0.075856      0.003903         0.014942        0.003826     100
# 15       0.089031      0.004447         0.016728        0.003455     100
#
#    param_gamma param_kernel  \
# 0        scale          rbf
# 1        scale       linear
# 2        scale         poly
# 3        scale      sigmoid
# 4         auto          rbf
# 5         auto       linear
# 6         auto         poly
# 7         auto      sigmoid
# 8        scale          rbf
# 9        scale       linear
# 10       scale         poly
# 11       scale      sigmoid
# 12        auto          rbf
# 13        auto       linear
# 14        auto         poly
# 15        auto      sigmoid
#
#                                                params  split0_test_score  \
# 0        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}           0.004126
# 1     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.377969
# 2       {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}           0.054964
# 3    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.049644
# 4         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}           0.004055
# 5      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.377969
# 6        {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           0.056274
# 7     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.049905
# 8       {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.301041
# 9    {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.584474
# 10     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.537117
# 11  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.478930
# 12       {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.300573
# 13    {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.584474
# 14      {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.540643
# 15   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.478364
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.013244          -0.103775          -0.095165
# 1            0.479601           0.317872           0.337979
# 2            0.071297          -0.046513          -0.024157
# 3            0.076323          -0.046798          -0.040824
# 4            0.013366          -0.103821          -0.095119
# 5            0.479601           0.317872           0.337979
# 6            0.069532          -0.045601          -0.025079
# 7            0.075905          -0.046585          -0.041004
# 8            0.338741           0.174086           0.217641
# 9            0.655818           0.553380           0.576939
# 10           0.579373           0.471840           0.537966
# 11           0.563200           0.427152           0.451250
# 12           0.339474           0.173708           0.217991
# 13           0.655818           0.553380           0.576939
# 14           0.575051           0.474839           0.535730
# 15           0.561673           0.428331           0.450454
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.101602        -0.056634        0.053486               16
# 1            0.324422         0.367569        0.059777                7
# 2           -0.049652         0.001188        0.051594               11
# 3           -0.046521        -0.001635        0.053474               13
# 4           -0.101604        -0.056625        0.053504               15
# 5            0.324422         0.367569        0.059777                7
# 6           -0.049592         0.001107        0.051309               12
# 7           -0.046507        -0.001657        0.053391               14
# 8            0.183403         0.242982        0.065542               10
# 9            0.546881         0.583498        0.038787                1
# 10           0.424478         0.510155        0.054955                4
# 11           0.432199         0.470546        0.049762                5
# 12           0.183375         0.243024        0.065733                9
# 13           0.546881         0.583498        0.038787                1
# 14           0.424640         0.510181        0.053582                3
# 15           0.431701         0.470105        0.049110                6

# %%
print(f"The R score value for best parameter: {grid.best_params_} ")
# Out:
# The R score value for best parameter: {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}
