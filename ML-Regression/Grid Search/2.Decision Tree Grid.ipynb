# %%
import pandas as pd

# %%
dataset = pd.read_csv('insurance_pre.csv')
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset, dtype=int, drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children',  'sex_male', 'smoker_yes']]
dependent= dataset[['charges']]

# %%
# from sklearn.model_selection import train_test_split
# x_train, x_test, y_train, y_test = train_test_split(independent, dependent, test_size=0.30, random_state=0)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor

param_grid = {
    'criterion': ['squared_error','absolute_error','friedman_mse','poisson'],
    'splitter': ['best','random'],
    'max_features': ['sqrt','log2', None]
}

grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit=True, verbose=3, n_jobs=None)
grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 1/5] END criterion=squared_error, max_features=sqrt, splitter=best;, score=0.768 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_features=sqrt, splitter=best;, score=0.621 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_features=sqrt, splitter=best;, score=0.711 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_features=sqrt, splitter=best;, score=0.627 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_features=sqrt, splitter=best;, score=0.695 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_features=sqrt, splitter=random;, score=0.676 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_features=sqrt, splitter=random;, score=0.617 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_features=sqrt, splitter=random;, score=0.669 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_features=sqrt, splitter=random;, score=0.704 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_features=sqrt, splitter=random;, score=0.582 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_features=log2, splitter=best;, score=0.730 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_features=log2, splitter=best;, score=0.635 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_features=log2, splitter=best;, score=0.643 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_features=log2, splitter=best;, score=0.690 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_features=log2, splitter=best;, score=0.684 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_features=log2, splitter=random;, score=0.693 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_features=log2, splitter=random;, score=0.484 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_features=log2, splitter=random;, score=0.669 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_features=log2, splitter=random;, score=0.677 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_features=log2, splitter=random;, score=0.705 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_features=None, splitter=best;, score=0.723 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_features=None, splitter=best;, score=0.639 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_features=None, splitter=best;, score=0.739 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_features=None, splitter=best;, score=0.702 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_features=None, splitter=best;, score=0.665 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_features=None, splitter=random;, score=0.667 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_features=None, splitter=random;, score=0.586 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_features=None, splitter=random;, score=0.670 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_features=None, splitter=random;, score=0.730 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_features=None, splitter=random;, score=0.700 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_features=sqrt, splitter=best;, score=0.579 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_features=sqrt, splitter=best;, score=0.686 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_features=sqrt, splitter=best;, score=0.684 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_features=sqrt, splitter=best;, score=0.757 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_features=sqrt, splitter=best;, score=0.762 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_features=sqrt, splitter=random;, score=0.739 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_features=sqrt, splitter=random;, score=0.606 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_features=sqrt, splitter=random;, score=0.545 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_features=sqrt, splitter=random;, score=0.719 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_features=sqrt, splitter=random;, score=0.579 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_features=log2, splitter=best;, score=0.707 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_features=log2, splitter=best;, score=0.608 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_features=log2, splitter=best;, score=0.630 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_features=log2, splitter=best;, score=0.711 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_features=log2, splitter=best;, score=0.711 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_features=log2, splitter=random;, score=0.750 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_features=log2, splitter=random;, score=0.613 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_features=log2, splitter=random;, score=0.537 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_features=log2, splitter=random;, score=0.740 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_features=log2, splitter=random;, score=0.712 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_features=None, splitter=best;, score=0.737 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_features=None, splitter=best;, score=0.655 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_features=None, splitter=best;, score=0.738 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_features=None, splitter=best;, score=0.715 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_features=None, splitter=best;, score=0.738 total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_features=None, splitter=random;, score=0.646 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_features=None, splitter=random;, score=0.611 total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_features=None, splitter=random;, score=0.721 total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_features=None, splitter=random;, score=0.712 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_features=None, splitter=random;, score=0.697 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_features=sqrt, splitter=best;, score=0.696 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=sqrt, splitter=best;, score=0.609 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=sqrt, splitter=best;, score=0.706 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=sqrt, splitter=best;, score=0.746 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=sqrt, splitter=best;, score=0.609 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_features=sqrt, splitter=random;, score=0.714 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=sqrt, splitter=random;, score=0.525 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=sqrt, splitter=random;, score=0.671 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=sqrt, splitter=random;, score=0.628 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=sqrt, splitter=random;, score=0.681 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_features=log2, splitter=best;, score=0.673 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=log2, splitter=best;, score=0.573 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=log2, splitter=best;, score=0.675 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=log2, splitter=best;, score=0.701 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=log2, splitter=best;, score=0.673 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_features=log2, splitter=random;, score=0.733 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=log2, splitter=random;, score=0.549 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=log2, splitter=random;, score=0.701 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=log2, splitter=random;, score=0.652 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=log2, splitter=random;, score=0.645 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_features=None, splitter=best;, score=0.709 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=None, splitter=best;, score=0.649 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=None, splitter=best;, score=0.731 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=None, splitter=best;, score=0.709 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=None, splitter=best;, score=0.675 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_features=None, splitter=random;, score=0.621 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_features=None, splitter=random;, score=0.645 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_features=None, splitter=random;, score=0.746 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_features=None, splitter=random;, score=0.689 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_features=None, splitter=random;, score=0.726 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_features=sqrt, splitter=best;, score=0.697 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_features=sqrt, splitter=best;, score=0.664 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_features=sqrt, splitter=best;, score=0.722 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_features=sqrt, splitter=best;, score=0.599 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_features=sqrt, splitter=best;, score=0.734 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_features=sqrt, splitter=random;, score=0.663 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_features=sqrt, splitter=random;, score=0.625 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_features=sqrt, splitter=random;, score=0.669 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_features=sqrt, splitter=random;, score=0.713 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_features=sqrt, splitter=random;, score=0.676 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_features=log2, splitter=best;, score=0.696 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_features=log2, splitter=best;, score=0.639 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_features=log2, splitter=best;, score=0.466 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_features=log2, splitter=best;, score=0.636 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_features=log2, splitter=best;, score=0.736 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_features=log2, splitter=random;, score=0.738 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_features=log2, splitter=random;, score=0.591 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_features=log2, splitter=random;, score=0.606 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_features=log2, splitter=random;, score=0.722 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_features=log2, splitter=random;, score=0.626 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_features=None, splitter=best;, score=0.751 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_features=None, splitter=best;, score=0.651 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_features=None, splitter=best;, score=0.774 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_features=None, splitter=best;, score=0.731 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_features=None, splitter=best;, score=0.683 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_features=None, splitter=random;, score=0.718 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_features=None, splitter=random;, score=0.573 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_features=None, splitter=random;, score=0.738 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_features=None, splitter=random;, score=0.716 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_features=None, splitter=random;, score=0.756 total time=   0.0s
# GridSearchCV(estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re = grid.cv_results_

# %%
table = pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.006000  6.319452e-04         0.002999    2.861023e-07
# 1        0.004597  4.894537e-04         0.002399    4.893758e-04
# 2        0.005396  4.897847e-04         0.002599    4.896678e-04
# 3        0.004397  4.899220e-04         0.002599    4.896485e-04
# 4        0.006995  1.016010e-06         0.002795    3.980241e-04
# 5        0.006590  2.244697e-03         0.003805    1.178451e-03
# 6        0.020786  1.469238e-03         0.003400    4.900413e-04
# 7        0.015392  2.248351e-03         0.002995    8.895906e-04
# 8        0.018188  9.794525e-04         0.002600    4.899988e-04
# 9        0.016393  2.155092e-03         0.003196    9.730995e-04
# 10       0.032983  8.983314e-04         0.002796    7.409160e-04
# 11       0.025784  2.784216e-03         0.003000    5.352484e-07
# 12       0.007595  1.852441e-03         0.004398    1.199317e-03
# 13       0.006595  2.151944e-03         0.003599    8.004428e-04
# 14       0.006995  8.943112e-04         0.003399    1.355503e-03
# 15       0.004197  3.997328e-04         0.002599    4.892590e-04
# 16       0.006595  4.897067e-04         0.002600    4.895510e-04
# 17       0.004796  3.995183e-04         0.002599    4.893369e-04
# 18       0.005995  6.323343e-04         0.002400    4.894147e-04
# 19       0.006396  1.495612e-03         0.003199    3.994969e-04
# 20       0.006195  4.003292e-04         0.002600    4.897655e-04
# 21       0.004801  4.013959e-04         0.002799    3.995898e-04
# 22       0.007995  4.909339e-07         0.002999    4.101908e-07
# 23       0.006996  2.099908e-03         0.003595    1.187257e-03
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4    squared_error               None           best
# 5    squared_error               None         random
# 6   absolute_error               sqrt           best
# 7   absolute_error               sqrt         random
# 8   absolute_error               log2           best
# 9   absolute_error               log2         random
# 10  absolute_error               None           best
# 11  absolute_error               None         random
# 12    friedman_mse               sqrt           best
# 13    friedman_mse               sqrt         random
# 14    friedman_mse               log2           best
# 15    friedman_mse               log2         random
# 16    friedman_mse               None           best
# 17    friedman_mse               None         random
# 18         poisson               sqrt           best
# 19         poisson               sqrt         random
# 20         poisson               log2           best
# 21         poisson               log2         random
# 22         poisson               None           best
# 23         poisson               None         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.767987
# 1   {'criterion': 'squared_error', 'max_features':...           0.675712
# 2   {'criterion': 'squared_error', 'max_features':...           0.730268
# 3   {'criterion': 'squared_error', 'max_features':...           0.692567
# 4   {'criterion': 'squared_error', 'max_features':...           0.723003
# 5   {'criterion': 'squared_error', 'max_features':...           0.666725
# 6   {'criterion': 'absolute_error', 'max_features'...           0.578925
# 7   {'criterion': 'absolute_error', 'max_features'...           0.739058
# 8   {'criterion': 'absolute_error', 'max_features'...           0.706890
# 9   {'criterion': 'absolute_error', 'max_features'...           0.749851
# 10  {'criterion': 'absolute_error', 'max_features'...           0.737096
# 11  {'criterion': 'absolute_error', 'max_features'...           0.646186
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.696389
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.714108
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.672677
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.733462
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.708530
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.621036
# 18  {'criterion': 'poisson', 'max_features': 'sqrt...           0.696682
# 19  {'criterion': 'poisson', 'max_features': 'sqrt...           0.663356
# 20  {'criterion': 'poisson', 'max_features': 'log2...           0.696121
# 21  {'criterion': 'poisson', 'max_features': 'log2...           0.738475
# 22  {'criterion': 'poisson', 'max_features': None,...           0.751254
# 23  {'criterion': 'poisson', 'max_features': None,...           0.717557
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.620937           0.711421           0.627440
# 1            0.617098           0.668702           0.703517
# 2            0.634762           0.642880           0.689842
# 3            0.484431           0.669327           0.676586
# 4            0.638606           0.738804           0.701624
# 5            0.585642           0.669733           0.729898
# 6            0.686465           0.684215           0.756995
# 7            0.605583           0.545107           0.718973
# 8            0.607820           0.630202           0.711175
# 9            0.613344           0.536747           0.739694
# 10           0.654549           0.737578           0.714804
# 11           0.611024           0.720583           0.711728
# 12           0.608911           0.706449           0.745871
# 13           0.524781           0.670589           0.628411
# 14           0.572947           0.674836           0.700669
# 15           0.549465           0.700648           0.652065
# 16           0.649014           0.730885           0.709151
# 17           0.644845           0.746117           0.688995
# 18           0.663861           0.721929           0.599116
# 19           0.624663           0.669248           0.712783
# 20           0.638505           0.465555           0.636043
# 21           0.590704           0.606275           0.721816
# 22           0.650877           0.773773           0.730591
# 23           0.573100           0.737822           0.716131
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.695457         0.684648        0.054974                8
# 1            0.581686         0.649343        0.043868               20
# 2            0.683739         0.676298        0.034623               11
# 3            0.705275         0.645637        0.081566               21
# 4            0.664857         0.693379        0.036940                6
# 5            0.699984         0.670396        0.048193               14
# 6            0.762158         0.693751        0.066345                5
# 7            0.579135         0.637571        0.077348               23
# 8            0.710502         0.673318        0.044926               13
# 9            0.711584         0.670244        0.082375               15
# 10           0.738107         0.716427        0.032175                2
# 11           0.697370         0.677378        0.042005               10
# 12           0.609239         0.673372        0.055042               12
# 13           0.681069         0.643791        0.065501               22
# 14           0.673165         0.658859        0.044226               17
# 15           0.644951         0.656118        0.062420               19
# 16           0.675151         0.694546        0.028909                4
# 17           0.726105         0.685420        0.047210                7
# 18           0.733760         0.683070        0.048336                9
# 19           0.676061         0.669222        0.028158               16
# 20           0.736233         0.634491        0.092420               24
# 21           0.626085         0.656671        0.061258               18
# 22           0.682963         0.717892        0.044962                1
# 23           0.756181         0.700158        0.065206                3

# %%
# y_pred=grid.predict(x_test)
# from sklearn.metrics import r2_score
# r_score=r2_score(y_test, y_pred)
print("R Score for the best parameter : {}".format(grid.best_params_))
# Out:
# R Score for the best parameter : {'criterion': 'poisson', 'max_features': None, 'splitter': 'best'}
